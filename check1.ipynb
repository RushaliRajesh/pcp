# %%
import numpy as np 
from joblib import Parallel, delayed
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
import open3d as o3d
from scipy.optimize import minimize
from scipy.linalg import lstsq

path_norm = "pclouds/boxunion_uniform100k_ddist_minmax_layers.normals"
path_curv = "pclouds/armadillo100k_ddist_minmax_layers.curv"
path_pcd = "pclouds/boxunion_uniform100k_ddist_minmax_layers.xyz"

normals = np.loadtxt(path_norm)
points = np.loadtxt(path_pcd)
curvs = np.loadtxt(path_curv)
# print(normals.shape, pcd.shape)    

'''visualization'''

pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points)
pcd.normals = o3d.utility.Vector3dVector(normals)
o3d.visualization.draw_geometries([pcd], point_show_normal=True)

'''neighborhood (normal init)'''

def find_neighs(points, k=250):
    nbrs = NearestNeighbors(n_neighbors=k, algorithm= 'kd_tree').fit(points)
    distances, indices = nbrs.kneighbors(points) 
    return distances, indices

def pca_plane(points):
    # print(points.shape)
    pca = PCA(n_components=3)
    pca.fit(points)
    return pca.components_[2]/np.linalg.norm(pca.components_[2])

def scipy_ls(points):
    a = np.hstack((points[:, :2], np.ones(points.shape[0]).reshape(-1, 1)))
    b= points[:, 2]
    abc, residue, rank, s = lstsq(a, b) 
    return abc/np.linalg.norm(abc)

def plane_cost(params, points):
    a, b, c, d = params
    # Compute the signed distances from each point to the plane
    distances = np.abs(a * points[:, 0] + b * points[:, 1] + c * points[:, 2] + d) / np.sqrt(a**2 + b**2 + c**2)
    # Return the sum of squared distances as the cost
    return np.sum(distances**2)

def scipy_min(points):
    ini_guess= np.array([1.0,1.0,1.0,1.0])
    res = minimize(plane_cost, ini_guess, args=(points), method='Nelder-Mead', tol=1e-6)
    return res.x[:3]/np.linalg.norm(res.x[:3])

dists, indices = find_neighs(points, 250)
# print(pcd[indices].shape)
neighs = points[indices]

norm_esti_pca = Parallel(n_jobs=-1)(delayed(pca_plane)(point_neighs) for point_neighs in neighs)
# norm_esti_ls = Parallel(n_jobs=-1)(delayed(scipy_ls)(point_neighs) for point_neighs in neighs)
# norm_esti_min = Parallel(n_jobs=-1)(delayed(scipy_min)(point_neighs) for point_neighs in neighs)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
print(norm_esti_pca[0], norm_esti_pca[1])
print(normals[0], normals[1])
print(np.dot(norm_esti_pca[0], normals[0]), np.dot(norm_esti_pca[1], normals[1]))
# Out:
# [ 0. -1.  0.] [-0.23809519  0.28105998  0.92968595]
# [ 0.  1. -0.] [-0.  0. -1.]
# -1.0 -0.9296859511003669

# %%
np.diag(np.dot(norm_esti_pca[:60000] , normals[:60000].T))

# %%
memory_size_bytes = 400000
memory_size_gb = memory_size_bytes / (1024 ** 3)

print(f"Memory size: {memory_size_gb:.2f} GB")
# Out:
# Memory size: 0.00 GB

# %%
norm_= normals/np.linalg.norm(normals, axis=1)[:,np.newaxis]
dot_pca = np.abs(np.diag(np.dot(norm_esti_pca[:2048] , norm_[:2048,:].T))).mean()
# dot_ls = np.abs(np.diag(np.dot(norm_esti_ls[:300] , norm_[:300,:].T))).mean()
# dot_min = np.abs(np.diag(np.dot(norm_esti_min[:300] , norm_[:300,:].T))).mean()

# print(dot_pca, dot_ls, dot_min)
print(dot_pca)
# Out:
# 0.9642755525983011

# %%
type(norm_)
# Out:
# numpy.ndarray

# %%
import os

    # Get a list of all files in the folder
files = os.listdir("pclouds")

# Create a dictionary to store file lists based on extensions
file_dict = {}

# Iterate over each file and categorize based on extension
for file in files:
    filename, extension = os.path.splitext(file)
    print(filename, extension)
    break
# Out:
# armadillo100k_noise_brown_4.00e-02 .curv
# Boxy_smooth100k_noise_white_1.00e-02 .pidx
# armadillo100k_noise_white_8.00e-02 .xyz
# sheet_analytic100k_noise_white_1.00e-02 .pidx
# fandisk100k_noise_brown_5.00e-02 .xyz
# sphere_analytic100k_noise_white_8.00e-02 .xyz
# netsuke100k_noise_white_7.00e-02 .normals
# galera100k_noise_white_1.00e-01 .curv
# sphere100k_ddist_minmax_layers .curv
# boxunion2100k_noise_white_5.00e-02 .normals
# armadillo100k_noise_white_1.00e-02 .curv
# icosahedron100k_ddist_minmax_layers .normals
# boxunion2100k_noise_white_8.00e-02 .xyz
# star_smooth100k_noise_white_7.00e-02 .curv
# star_smooth100k_noise_white_1.00e-01 .pidx
# pipe100k_ddist_minmax .xyz
# Cup34100k_ddist_minmax_layers .normals
# galera100k_ddist_minmax .pidx
# cylinder_analytic100k_noise_white_3.00e-02 .normals
# flower100k_noise_white_9.00e-02 .xyz
# flower100k_noise_white_4.00e-02 .curv
# icosahedron100k_noise_white_2.00e-02 .normals
# tortuga100k_ddist_minmax_layers .pidx
# boxunion2100k .curv
# boxunion_uniform100k .curv
# Liberty100k_noise_white_1.00e-01 .xyz
# star_halfsmooth100k_noise_white_1.00e-01 .normals
# pipe_curve100k .pidx
# column100k_noise_white_1.00e-02 .normals
# netsuke100k_ddist_minmax_layers .xyz
# boxunion2100k_ddist_minmax .xyz
# armadillo100k_noise_white_8.00e-02 .normals
# star_halfsmooth100k_noise_white_4.00e-02 .normals
# bunny100k_noise_brown_7.00e-02 .normals
# star_halfsmooth100k_noise_white_7.00e-02 .normals
# bunny100k_noise_white_5.00e-02 .pidx
# sphere100k_ddist_minmax .normals
# dragon_xyzrgb100k .curv
# sphere100k_noise_white_1.00e-01 .xyz
# pipe_curve100k_noise_white_4.00e-02 .normals
# pipe100k_ddist_minmax .pidx
# dragon_xyzrgb100k_ddist_minmax_layers .pidx
# Boxy_smooth100k .curv
# boxunion2100k_noise_white_4.00e-02 .curv
# tortuga100k_ddist_minmax .normals
# armadillo100k_noise_brown_8.00e-02 .curv
# sphere_analytic100k_noise_white_3.00e-02 .xyz
# sphere_analytic100k .xyz
# bunny100k_noise_white_8.00e-02 .normals
# armadillo100k_noise_brown_1.00e-02 .xyz
# sphere_analytic100k_noise_white_1.00e-02 .pidx
# bunny100k_noise_white_1.00e-01 .curv
# sheet_analytic100k_noise_white_3.00e-02 .normals
# Cup33100k_noise_white_9.00e-02 .curv
# sphere100k_noise_white_7.00e-02 .curv
# star_smooth100k .normals
# cylinder_analytic100k .curv
# column_head100k .normals
# galera100k_noise_white_4.00e-02 .curv
# bunny100k_noise_white_1.00e-01 .pidx
# galera100k_noise_white_7.00e-02 .normals
# cylinder_analytic100k_noise_white_2.00e-02 .xyz
# Cup33100k_noise_white_4.00e-02 .curv
# sphere_analytic100k_noise_white_8.00e-02 .curv
# sphere100k_noise_white_5.00e-02 .pidx
# boxunion_uniform100k_ddist_minmax_layers .curv
# flower100k_noise_white_9.00e-02 .curv
# icosahedron100k_noise_white_7.00e-02 .xyz
# armadillo100k_noise_brown_4.00e-02 .xyz
# fandisk100k_noise_white_6.00e-02 .curv
# icosahedron100k_noise_white_9.00e-02 .xyz
# Liberty100k_noise_white_9.00e-02 .curv
# fandisk100k_noise_brown_1.00e-01 .curv
# sphere100k_noise_white_1.00e-02 .curv
# bunny100k_noise_brown_4.00e-02 .curv
# validationset_no_noise .txt
# Cup33100k_ddist_minmax_layers .pidx
# column_head100k_ddist_minmax_layers .xyz
# boxunion_uniform100k_noise_white_5.00e-02 .normals
# Cup34100k_ddist_minmax_layers .curv
# sphere_analytic100k .normals
# cylinder100k_ddist_minmax_layers .xyz
# Liberty100k_noise_white_6.00e-02 .normals
# star_sharp100k_noise_white_9.00e-02 .normals
# icosahedron100k_noise_white_9.00e-02 .curv
# Cup33100k_noise_white_1.00e-02 .xyz
# netsuke100k_noise_white_5.00e-02 .xyz
# column_head100k_noise_white_5.00e-02 .pidx
# star_halfsmooth100k_noise_white_2.00e-02 .normals
# boxunion2100k_noise_white_1.00e-02 .normals
# bunny100k_noise_white_5.00e-02 .xyz
# column100k_noise_white_6.00e-02 .normals
# bunny100k_noise_brown_6.00e-02 .normals
# star_smooth100k_noise_white_8.00e-02 .normals
# Boxy_smooth100k .pidx
# pipe_curve100k .normals
# fandisk100k_ddist_minmax_layers .pidx
# cylinder100k_noise_white_7.00e-02 .xyz
# column_head100k .curv
# Liberty100k_noise_white_2.00e-02 .normals
# icosahedron100k_noise_white_8.00e-02 .curv
# star_halfsmooth100k_noise_white_4.00e-02 .curv
# tortuga100k_noise_white_3.00e-02 .curv
# galera100k_noise_white_6.00e-02 .curv
# flower100k_noise_white_1.00e-02 .pidx
# sheet_analytic100k .normals
# Cup33100k_noise_white_1.00e-01 .pidx
# nyu_4_whitenoise .xyz
# boxunion_uniform100k_noise_white_5.00e-02 .pidx
# pipe_curve100k_ddist_minmax .xyz
# sphere100k_noise_white_4.00e-02 .normals
# Cup33100k_noise_white_4.00e-02 .normals
# dragon_xyzrgb100k .pidx
# column_head100k_ddist_minmax .normals
# sheet_analytic100k_noise_white_1.00e-01 .curv
# tortuga100k_ddist_minmax .pidx
# armadillo100k_noise_brown_8.00e-02 .normals
# pipe_curve100k_noise_white_3.00e-02 .xyz
# Cup34100k_noise_white_1.00e-02 .curv
# sphere100k_noise_white_4.00e-02 .xyz
# cylinder100k_noise_white_1.00e-02 .normals
# armadillo100k_noise_brown_7.00e-02 .xyz
# star_smooth100k_noise_white_1.00e-02 .normals
# Cup34100k_noise_white_7.00e-02 .xyz
# bunny100k_noise_white_1.00e-02 .pidx
# star_sharp100k_noise_white_2.00e-02 .xyz
# star_sharp100k .xyz
# netsuke100k_ddist_minmax .normals
# star_smooth100k_noise_white_7.00e-02 .normals
# Liberty100k_noise_white_3.00e-02 .normals
# boxunion2100k_noise_white_8.00e-02 .normals
# cylinder100k_noise_white_5.00e-02 .normals
# armadillo100k_noise_white_5.00e-02 .curv
# cylinder100k .normals
# icosahedron100k_noise_white_2.00e-02 .curv
# tortuga100k_noise_white_2.00e-02 .normals
# Cup33100k_noise_white_1.00e-02 .normals
# dragon_xyzrgb100k_noise_white_1.00e-01 .pidx
# cylinder100k_ddist_minmax .normals
# Boxy_smooth100k_noise_white_3.00e-02 .curv
# column100k_noise_white_1.00e-02 .curv
# pipe100k_noise_white_8.00e-02 .curv
# Cup34100k_ddist_minmax .pidx
# pipe_curve100k_ddist_minmax .pidx
# column_head100k_noise_white_2.00e-02 .xyz
# galera100k_ddist_minmax .normals
# star_smooth100k_noise_white_5.00e-02 .xyz
# fandisk100k_noise_brown_7.00e-02 .curv
# pipe_curve100k_noise_white_6.00e-02 .normals
# boxunion2100k_noise_white_5.00e-02 .pidx
# armadillo100k_noise_white_7.00e-02 .curv
# column100k_noise_white_1.00e-01 .pidx
# sphere100k_noise_white_6.00e-02 .xyz
# Cup34100k_ddist_minmax .xyz
# netsuke100k_noise_white_2.00e-02 .normals
# icosahedron100k_noise_white_1.00e-02 .normals
# cylinder100k_noise_white_7.00e-02 .curv
# bunny100k_noise_brown_3.00e-02 .xyz
# netsuke100k_noise_white_4.00e-02 .xyz
# column_head100k_noise_white_1.00e-02 .pidx
# star_smooth100k_noise_white_8.00e-02 .xyz
# pipe100k_noise_white_1.00e-01 .xyz
# column_head100k_noise_white_6.00e-02 .xyz
# icosahedron100k_noise_white_2.00e-02 .xyz
# cylinder100k_noise_white_9.00e-02 .xyz
# Boxy_smooth100k_ddist_minmax_layers .xyz
# fandisk100k_noise_brown_8.00e-02 .normals
# flower100k_noise_white_9.00e-02 .normals
# Liberty100k_ddist_minmax_layers .xyz
# sheet_analytic100k_noise_white_6.00e-02 .curv
# icosahedron100k_noise_white_5.00e-02 .pidx
# boxunion_uniform100k_noise_white_6.00e-02 .xyz
# Liberty100k_noise_white_7.00e-02 .xyz
# sphere100k .normals
# armadillo100k_noise_brown_1.00e-01 .normals
# dragon_xyzrgb100k_noise_white_7.00e-02 .curv
# boxunion2100k_noise_white_1.00e-01 .normals
# star_smooth100k_ddist_minmax .pidx
# column_head100k_noise_white_1.00e-02 .curv
# Cup33100k_noise_white_6.00e-02 .xyz
# galera100k_noise_white_1.00e-02 .pidx
# star_sharp100k_noise_white_1.00e-01 .xyz
# star_sharp100k .normals
# column_head100k_noise_white_9.00e-02 .normals
# boxunion2100k_noise_white_3.00e-02 .xyz
# pipe_curve100k_noise_white_1.00e-01 .xyz
# boxunion_uniform100k_noise_white_8.00e-02 .xyz
# Boxy_smooth100k_noise_white_9.00e-02 .curv
# dragon_xyzrgb100k_noise_white_1.00e-02 .curv
# pipe_curve100k_noise_white_2.00e-02 .xyz
# armadillo100k_noise_white_1.00e-02 .normals
# boxunion_uniform100k_noise_brown_6.00e-02 .normals
# armadillo100k_noise_brown_3.00e-02 .xyz
# Liberty100k_noise_white_1.00e-01 .curv
# boxunion2100k_ddist_minmax_layers .xyz
# fandisk100k_noise_white_1.00e-01 .xyz
# boxunion_uniform100k_noise_brown_1.00e-02 .curv
# sheet_analytic100k_noise_white_3.00e-02 .curv
# fandisk100k_noise_white_5.00e-02 .pidx
# fandisk100k_noise_white_7.00e-02 .normals
# star_halfsmooth100k_noise_white_8.00e-02 .xyz
# tortuga100k_noise_white_1.00e-02 .xyz
# boxunion_uniform100k_noise_white_1.00e-01 .normals
# boxunion_uniform100k_noise_white_4.00e-02 .normals
# armadillo100k_noise_white_5.00e-02 .xyz
# armadillo100k_noise_white_1.00e-01 .normals
# pipe_curve100k_noise_white_2.00e-02 .curv
# sphere_analytic100k_noise_white_2.00e-02 .xyz
# armadillo100k_noise_brown_9.00e-02 .xyz
# icosahedron100k_noise_white_1.00e-02 .pidx
# Liberty100k_noise_white_6.00e-02 .curv
# star_smooth100k_ddist_minmax_layers .xyz
# fandisk100k_noise_brown_2.00e-02 .xyz
# pipe100k_noise_white_7.00e-02 .normals
# sheet_analytic100k .xyz
# star_smooth100k_ddist_minmax .normals
# Boxy_smooth100k_noise_white_2.00e-02 .xyz
# cylinder_analytic100k_noise_white_1.00e-02 .curv
# Cup34100k_noise_white_2.00e-02 .normals
# fandisk100k_ddist_minmax .curv
# star_sharp100k_noise_white_1.00e-02 .curv
# galera100k_noise_white_1.00e-01 .pidx
# bunny100k_ddist_minmax_layers .xyz
# bunny100k .curv
# column100k_noise_white_9.00e-02 .xyz
# sheet_analytic100k_noise_white_2.00e-02 .xyz
# netsuke100k_noise_white_3.00e-02 .curv
# boxunion_uniform100k_noise_brown_6.00e-02 .xyz
# flower100k_noise_white_5.00e-02 .xyz
# column_head100k_noise_white_6.00e-02 .normals
# fandisk100k_noise_brown_3.00e-02 .xyz
# cylinder_analytic100k_noise_white_7.00e-02 .curv
# column_head100k_ddist_minmax .curv
# pipe100k_noise_white_1.00e-02 .xyz
# star_smooth100k_noise_white_3.00e-02 .curv
# star_sharp100k_ddist_minmax .pidx
# galera100k .pidx
# bunny100k_noise_brown_4.00e-02 .xyz
# column_head100k_noise_white_8.00e-02 .normals
# tortuga100k .pidx
# sphere100k_noise_white_1.00e-01 .curv
# tortuga100k .xyz
# sphere100k_noise_white_1.00e-02 .xyz
# Boxy_smooth100k_noise_white_2.00e-02 .curv
# column_head100k_noise_white_9.00e-02 .xyz
# Boxy_smooth100k_ddist_minmax .curv
# boxunion2100k_ddist_minmax .curv
# icosahedron100k_noise_white_1.00e-01 .xyz
# galera100k_noise_white_5.00e-02 .normals
# boxunion2100k_noise_white_7.00e-02 .xyz
# column100k_ddist_minmax .normals
# cylinder100k_noise_white_1.00e-01 .pidx
# netsuke100k .curv
# cylinder100k_noise_white_1.00e-01 .curv
# icosahedron100k_ddist_minmax_layers .pidx
# pipe100k_noise_white_8.00e-02 .normals
# Cup34100k_noise_white_4.00e-02 .curv
# column100k_noise_white_5.00e-02 .xyz
# boxunion2100k_noise_white_8.00e-02 .curv
# star_halfsmooth100k_noise_white_5.00e-02 .xyz
# cylinder100k_noise_white_6.00e-02 .curv
# column100k_noise_white_7.00e-02 .curv
# Boxy_smooth100k_noise_white_4.00e-02 .normals
# Cup33100k_noise_white_3.00e-02 .curv
# bunny100k_noise_white_5.00e-02 .curv
# tortuga100k_noise_white_6.00e-02 .normals
# column_head100k_noise_white_4.00e-02 .curv
# Cup34100k_noise_white_1.00e-02 .pidx
# cylinder100k_noise_white_5.00e-02 .pidx
# Cup33100k_noise_white_1.00e-01 .normals
# fandisk100k_noise_white_9.00e-02 .curv
# column_head100k_noise_white_6.00e-02 .curv
# boxunion_uniform100k_noise_white_3.00e-02 .normals
# tortuga100k_noise_white_2.00e-02 .curv
# icosahedron100k_noise_white_3.00e-02 .xyz
# column100k_noise_white_1.00e-01 .curv
# boxunion_uniform100k_noise_white_5.00e-02 .xyz
# star_sharp100k_noise_white_7.00e-02 .normals
# pipe100k_noise_white_3.00e-02 .curv
# star_sharp100k_ddist_minmax_layers .curv
# sphere_analytic100k_noise_white_4.00e-02 .xyz
# tortuga100k_noise_white_3.00e-02 .xyz
# fandisk100k_noise_brown_1.00e-02 .normals
# Boxy_smooth100k_noise_white_5.00e-02 .normals
# pipe100k .curv
# Cup33100k_noise_white_3.00e-02 .normals
# column_head100k_noise_white_2.00e-02 .normals
# validationset_vardensity .txt
# galera100k_noise_white_6.00e-02 .normals
# armadillo100k .pidx
# boxunion_uniform100k_noise_brown_3.00e-02 .normals
# fandisk100k_noise_white_5.00e-02 .curv
# pipe_curve100k_noise_white_5.00e-02 .curv
# boxunion2100k_noise_white_4.00e-02 .xyz
# star_smooth100k_noise_white_5.00e-02 .pidx
# star_sharp100k_ddist_minmax .curv
# star_smooth100k_noise_white_1.00e-01 .curv
# Boxy_smooth100k_noise_white_6.00e-02 .xyz
# pipe100k_ddist_minmax .curv
# sheet_analytic100k_noise_white_7.00e-02 .xyz
# pipe100k_noise_white_1.00e-01 .curv
# testset_high_noise .txt
# Cup33100k_ddist_minmax .xyz
# Cup34100k .normals
# Liberty100k_noise_white_1.00e-02 .xyz
# armadillo100k_noise_brown_3.00e-02 .normals
# star_halfsmooth100k_noise_white_8.00e-02 .normals
# column100k_noise_white_3.00e-02 .curv
# boxunion_uniform100k_noise_brown_4.00e-02 .normals
# star_halfsmooth100k_noise_white_2.00e-02 .curv
# Boxy_smooth100k_noise_white_3.00e-02 .xyz
# armadillo100k_noise_brown_1.00e-01 .curv
# pipe_curve100k_noise_white_5.00e-02 .pidx
# galera100k_noise_white_3.00e-02 .normals
# star_halfsmooth100k_noise_white_1.00e-02 .xyz
# pipe100k_noise_white_3.00e-02 .xyz
# netsuke100k_noise_white_5.00e-02 .pidx
# star_smooth100k_noise_white_2.00e-02 .normals
# flower100k_ddist_minmax_layers .pidx
# pipe_curve100k_noise_white_2.00e-02 .normals
# star_sharp100k_noise_white_5.00e-02 .pidx
# pipe100k_noise_white_1.00e-02 .pidx
# sphere100k_noise_white_1.00e-01 .pidx
# cylinder_analytic100k_noise_white_1.00e-02 .pidx
# column100k_noise_white_7.00e-02 .xyz
# Cup34100k_noise_white_9.00e-02 .normals
# cylinder_analytic100k_noise_white_6.00e-02 .curv
# sphere_analytic100k_noise_white_1.00e-01 .xyz
# sphere100k_noise_white_8.00e-02 .curv
# armadillo100k_noise_white_9.00e-02 .xyz
# fandisk100k_noise_brown_8.00e-02 .curv
# dragon_xyzrgb100k_noise_white_2.00e-02 .curv
# boxunion_uniform100k_noise_white_3.00e-02 .curv
# netsuke100k_ddist_minmax_layers .normals
# cylinder_analytic100k_noise_white_1.00e-02 .normals
# column100k_noise_white_6.00e-02 .xyz
# cylinder100k_noise_white_2.00e-02 .xyz
# star_sharp100k .pidx
# star_sharp100k_noise_white_3.00e-02 .normals
# Liberty100k_noise_white_9.00e-02 .normals
# star_sharp100k_noise_white_1.00e-01 .normals
# tortuga100k_noise_white_1.00e-02 .pidx
# Cup34100k_noise_white_8.00e-02 .normals
# armadillo100k_noise_white_2.00e-02 .xyz
# star_halfsmooth100k_noise_white_1.00e-01 .curv
# star_sharp100k_noise_white_8.00e-02 .curv
# fandisk100k_noise_brown_1.00e-02 .curv
# tortuga100k_noise_white_3.00e-02 .normals
# icosahedron100k_noise_white_6.00e-02 .xyz
# pipe_curve100k_noise_white_7.00e-02 .normals
# Cup33100k_noise_white_9.00e-02 .normals
# icosahedron100k_noise_white_6.00e-02 .curv
# boxunion_uniform100k_noise_brown_5.00e-02 .normals
# flower100k_ddist_minmax .pidx
# star_sharp100k_noise_white_3.00e-02 .xyz
# dragon_xyzrgb100k_noise_white_5.00e-02 .normals
# star_sharp100k_noise_white_7.00e-02 .curv
# pipe100k_noise_white_1.00e-01 .pidx
# sheet_analytic100k_noise_white_7.00e-02 .normals
# boxunion_uniform100k_noise_white_8.00e-02 .curv
# star_smooth100k_noise_white_4.00e-02 .normals
# icosahedron100k_ddist_minmax .curv
# boxunion_uniform100k_ddist_minmax_layers .pidx
# fandisk100k_noise_brown_5.00e-02 .curv
# sphere_analytic100k_noise_white_5.00e-02 .curv
# netsuke100k_noise_white_8.00e-02 .curv
# star_halfsmooth100k_noise_white_1.00e-02 .curv
# star_sharp100k_noise_white_8.00e-02 .xyz
# star_sharp100k_noise_white_2.00e-02 .curv
# bunny100k_noise_brown_5.00e-02 .curv
# sheet_analytic100k_noise_white_9.00e-02 .xyz
# flower100k_noise_white_2.00e-02 .normals
# column_head100k_ddist_minmax_layers .pidx
# cylinder100k_noise_white_9.00e-02 .curv
# bunny100k_noise_white_7.00e-02 .normals
# sphere100k_noise_white_3.00e-02 .xyz
# pipe_curve100k_ddist_minmax_layers .pidx
# boxunion_uniform100k .normals
# fandisk100k_noise_white_4.00e-02 .curv
# cylinder100k .xyz
# armadillo100k .curv
# fandisk100k_noise_white_3.00e-02 .normals
# icosahedron100k_noise_white_7.00e-02 .normals
# boxunion2100k_ddist_minmax_layers .pidx
# Cup33100k_noise_white_1.00e-01 .xyz
# Cup34100k_noise_white_8.00e-02 .xyz
# galera100k .curv
# Cup33100k_noise_white_7.00e-02 .curv
# flower100k .normals
# netsuke100k_noise_white_2.00e-02 .curv
# flower100k_noise_white_8.00e-02 .xyz
# column100k_noise_white_1.00e-02 .pidx
# Boxy_smooth100k_noise_white_6.00e-02 .normals
# boxunion_uniform100k_noise_brown_2.00e-02 .xyz
# column_head100k_noise_white_8.00e-02 .curv
# bunny100k_ddist_minmax .xyz
# sheet_analytic100k_noise_white_4.00e-02 .curv
# armadillo100k_ddist_minmax .xyz
# netsuke100k_noise_white_7.00e-02 .xyz
# star_smooth100k .xyz
# Boxy_smooth100k_noise_white_7.00e-02 .xyz
# icosahedron100k .pidx
# Cup34100k_ddist_minmax_layers .pidx
# sphere_analytic100k_noise_white_6.00e-02 .xyz
# netsuke100k_noise_white_1.00e-01 .xyz
# boxunion2100k_noise_white_1.00e-01 .curv
# pipe_curve100k_noise_white_6.00e-02 .curv
# fandisk100k_noise_white_2.00e-02 .xyz
# pipe100k_noise_white_2.00e-02 .curv
# netsuke100k_noise_white_9.00e-02 .xyz
# bunny100k_ddist_minmax .normals
# dragon_xyzrgb100k_noise_white_1.00e-01 .normals
# fandisk100k_noise_brown_8.00e-02 .xyz
# star_smooth100k_noise_white_6.00e-02 .xyz
# boxunion2100k_noise_white_9.00e-02 .curv
# sphere100k_noise_white_6.00e-02 .curv
# tortuga100k_noise_white_9.00e-02 .curv
# column100k_noise_white_8.00e-02 .xyz
# Boxy_smooth100k .normals
# icosahedron100k_noise_white_4.00e-02 .curv
# Boxy_smooth100k_noise_white_1.00e-02 .curv
# netsuke100k_noise_white_1.00e-01 .pidx
# fandisk100k_noise_brown_4.00e-02 .normals
# Cup33100k_noise_white_8.00e-02 .xyz
# sphere100k_noise_white_7.00e-02 .normals
# fandisk100k_noise_brown_9.00e-02 .normals
# bunny100k_noise_brown_6.00e-02 .xyz
# tortuga100k_noise_white_1.00e-01 .normals
# cylinder_analytic100k_noise_white_4.00e-02 .normals
# flower100k_noise_white_3.00e-02 .xyz
# star_halfsmooth100k_ddist_minmax .normals
# pipe_curve100k_noise_white_1.00e-02 .normals
# dragon_xyzrgb100k_noise_white_2.00e-02 .xyz
# column100k .curv
# sphere100k_noise_white_7.00e-02 .xyz
# armadillo100k_noise_brown_3.00e-02 .curv
# Cup33100k_noise_white_9.00e-02 .xyz
# bunny100k_noise_brown_8.00e-02 .curv
# pipe_curve100k_noise_white_1.00e-01 .pidx
# netsuke100k_noise_white_6.00e-02 .xyz
# column100k_ddist_minmax .curv
# cylinder100k_noise_white_1.00e-01 .xyz
# netsuke100k_noise_white_6.00e-02 .normals
# sphere100k_noise_white_5.00e-02 .xyz
# fandisk100k_noise_white_1.00e-02 .normals
# bunny100k_noise_white_3.00e-02 .normals
# Boxy_smooth100k_noise_white_7.00e-02 .curv
# star_sharp100k .curv
# bunny100k_noise_white_9.00e-02 .curv
# dragon_xyzrgb100k_noise_white_1.00e-01 .xyz
# tortuga100k_noise_white_5.00e-02 .pidx
# star_sharp100k_noise_white_6.00e-02 .normals
# star_smooth100k_noise_white_9.00e-02 .curv
# pipe_curve100k_ddist_minmax_layers .xyz
# armadillo100k_noise_white_1.00e-01 .xyz
# armadillo100k_noise_brown_1.00e-02 .normals
# flower100k_ddist_minmax .normals
# star_sharp100k_noise_white_9.00e-02 .curv
# fandisk100k_noise_white_3.00e-02 .curv
# tortuga100k_noise_white_1.00e-02 .normals
# Boxy_smooth100k_noise_white_7.00e-02 .normals
# Cup33100k .xyz
# Cup34100k_noise_white_7.00e-02 .normals
# pipe_curve100k_noise_white_5.00e-02 .normals
# bunny100k_ddist_minmax_layers .normals
# tortuga100k_noise_white_9.00e-02 .normals
# Cup33100k .normals
# star_halfsmooth100k_ddist_minmax .xyz
# boxunion_uniform100k_ddist_minmax_layers .normals
# Liberty100k_noise_white_4.00e-02 .xyz
# fandisk100k_noise_brown_2.00e-02 .curv
# netsuke100k_ddist_minmax_layers .curv
# star_sharp100k_noise_white_1.00e-01 .curv
# icosahedron100k_noise_white_4.00e-02 .xyz
# armadillo100k_noise_white_5.00e-02 .normals
# sphere_analytic100k_noise_white_1.00e-02 .normals
# column100k_noise_white_7.00e-02 .normals
# boxunion_uniform100k_ddist_minmax_layers .xyz
# boxunion_uniform100k_noise_white_4.00e-02 .xyz
# dragon_xyzrgb100k_noise_white_7.00e-02 .xyz
# flower100k_noise_white_4.00e-02 .normals
# galera100k_noise_white_2.00e-02 .xyz
# column100k_noise_white_1.00e-01 .xyz
# cylinder100k_noise_white_2.00e-02 .curv
# Liberty100k_ddist_minmax .pidx
# Liberty100k_noise_white_7.00e-02 .normals
# fandisk100k_noise_brown_4.00e-02 .curv
# Cup33100k_noise_white_8.00e-02 .normals
# star_halfsmooth100k_noise_white_7.00e-02 .xyz
# bunny100k_ddist_minmax_layers .pidx
# column_head100k_noise_white_3.00e-02 .normals
# tortuga100k_noise_white_1.00e-01 .pidx
# column100k_noise_white_9.00e-02 .normals
# Boxy_smooth100k_noise_white_6.00e-02 .curv
# bunny100k_noise_brown_7.00e-02 .curv
# sphere100k_noise_white_5.00e-02 .curv
# trainingset_vardensity_whitenoise .txt
# Liberty100k_noise_white_1.00e-01 .normals
# dragon_xyzrgb100k_noise_white_8.00e-02 .xyz
# Cup34100k_noise_white_5.00e-02 .pidx
# cylinder_analytic100k_noise_white_9.00e-02 .xyz
# sheet_analytic100k_noise_white_4.00e-02 .xyz
# galera100k_ddist_minmax_layers .curv
# bunny100k_noise_white_2.00e-02 .xyz
# icosahedron100k_noise_white_3.00e-02 .curv
# star_halfsmooth100k_ddist_minmax_layers .normals
# star_sharp100k_noise_white_4.00e-02 .xyz
# icosahedron100k_ddist_minmax_layers .curv
# sheet_analytic100k_noise_white_6.00e-02 .xyz
# dragon_xyzrgb100k .xyz
# fandisk100k_noise_white_1.00e-01 .pidx
# star_sharp100k_noise_white_5.00e-02 .curv
# column100k_noise_white_9.00e-02 .curv
# sphere100k_noise_white_9.00e-02 .normals
# Cup34100k_noise_white_7.00e-02 .curv
# Boxy_smooth100k_noise_white_5.00e-02 .xyz
# flower100k_ddist_minmax_layers .xyz
# validationset_vardensity_whitenoise .txt
# star_halfsmooth100k_noise_white_5.00e-02 .curv
# netsuke100k .normals
# Boxy_smooth100k_noise_white_8.00e-02 .xyz
# fandisk100k_noise_white_5.00e-02 .normals
# pipe_curve100k_noise_white_9.00e-02 .normals
# cylinder_analytic100k_noise_white_9.00e-02 .normals
# pipe100k_noise_white_1.00e-02 .curv
# armadillo100k_noise_white_3.00e-02 .curv
# fandisk100k .pidx
# sheet_analytic100k .pidx
# cylinder100k_noise_white_1.00e-01 .normals
# galera100k_noise_white_8.00e-02 .normals
# armadillo100k_noise_brown_6.00e-02 .xyz
# flower100k_noise_white_1.00e-01 .normals
# armadillo100k_ddist_minmax .pidx
# sheet_analytic100k_noise_white_2.00e-02 .curv
# tortuga100k_ddist_minmax_layers .normals
# sphere100k_noise_white_9.00e-02 .curv
# fandisk100k_noise_white_3.00e-02 .xyz
# Cup34100k .pidx
# Liberty100k_noise_white_2.00e-02 .xyz
# column100k_noise_white_2.00e-02 .normals
# testset_vardensity_striped .txt
# sphere_analytic100k_noise_white_4.00e-02 .normals
# star_halfsmooth100k_noise_white_4.00e-02 .xyz
# sphere_analytic100k_noise_white_5.00e-02 .pidx
# bunny100k_noise_brown_6.00e-02 .curv
# star_sharp100k_noise_white_9.00e-02 .xyz
# bunny100k_noise_brown_8.00e-02 .xyz
# boxunion2100k_noise_white_6.00e-02 .xyz
# Cup34100k_noise_white_3.00e-02 .curv
# pipe100k_noise_white_1.00e-01 .normals
# netsuke100k_ddist_minmax .curv
# fandisk100k_noise_brown_2.00e-02 .normals
# boxunion_uniform100k_noise_brown_3.00e-02 .xyz
# bunny100k_noise_brown_1.00e-02 .normals
# tortuga100k_noise_white_7.00e-02 .curv
# sphere100k_noise_white_1.00e-02 .pidx
# column_head100k_ddist_minmax .xyz
# fandisk100k .curv
# sphere_analytic100k_noise_white_3.00e-02 .normals
# galera100k_noise_white_7.00e-02 .curv
# Cup33100k_noise_white_6.00e-02 .normals
# boxunion_uniform100k_noise_white_5.00e-02 .curv
# bunny100k_noise_white_8.00e-02 .xyz
# Liberty100k_noise_white_6.00e-02 .xyz
# boxunion_uniform100k_noise_white_2.00e-02 .normals
# Cup34100k_noise_white_6.00e-02 .normals
# netsuke100k_noise_white_4.00e-02 .normals
# star_halfsmooth100k .pidx
# pipe100k_noise_white_2.00e-02 .normals
# sheet_analytic100k_noise_white_9.00e-02 .normals
# star_smooth100k_noise_white_3.00e-02 .normals
# fandisk100k_noise_white_6.00e-02 .xyz
# tortuga100k_noise_white_4.00e-02 .curv
# Cup33100k_ddist_minmax .normals
# netsuke100k_noise_white_1.00e-01 .curv
# fandisk100k_noise_brown_3.00e-02 .normals
# Cup33100k_ddist_minmax .pidx
# galera100k .xyz
# Cup33100k_noise_white_7.00e-02 .xyz
# sphere100k_ddist_minmax_layers .xyz
# netsuke100k_noise_white_8.00e-02 .xyz
# sheet_analytic100k_noise_white_9.00e-02 .curv
# testset_no_noise .txt
# galera100k_noise_white_8.00e-02 .xyz
# boxunion2100k_noise_white_5.00e-02 .curv
# star_sharp100k_ddist_minmax_layers .xyz
# sphere100k_noise_white_1.00e-02 .normals
# galera100k_noise_white_9.00e-02 .normals
# netsuke100k_noise_white_2.00e-02 .xyz
# star_smooth100k_ddist_minmax_layers .pidx
# cylinder_analytic100k_noise_white_1.00e-02 .xyz
# armadillo100k_noise_brown_1.00e-01 .xyz
# pipe100k_noise_white_8.00e-02 .xyz
# Cup33100k_noise_white_4.00e-02 .xyz
# bunny100k_noise_brown_1.00e-02 .curv
# dragon_xyzrgb100k_ddist_minmax_layers .normals
# pipe100k_noise_white_4.00e-02 .xyz
# galera100k_ddist_minmax .xyz
# dragon_xyzrgb100k_ddist_minmax .pidx
# column_head100k_noise_white_7.00e-02 .curv
# sheet_analytic100k_noise_white_3.00e-02 .xyz
# icosahedron100k_noise_white_8.00e-02 .normals
# fandisk100k_ddist_minmax_layers .normals
# dragon_xyzrgb100k_noise_white_5.00e-02 .xyz
# boxunion2100k_noise_white_2.00e-02 .curv
# bunny100k_noise_white_4.00e-02 .normals
# star_halfsmooth100k_noise_white_6.00e-02 .xyz
# star_halfsmooth100k_noise_white_6.00e-02 .curv
# Boxy_smooth100k .xyz
# star_sharp100k_noise_white_5.00e-02 .xyz
# pipe100k_ddist_minmax_layers .pidx
# netsuke100k_ddist_minmax .pidx
# cylinder_analytic100k_noise_white_2.00e-02 .curv
# sphere_analytic100k_noise_white_7.00e-02 .xyz
# netsuke100k .xyz
# cylinder_analytic100k_noise_white_8.00e-02 .curv
# sphere_analytic100k_noise_white_7.00e-02 .curv
# Cup34100k_noise_white_3.00e-02 .normals
# sphere100k .pidx
# Liberty100k .xyz
# Cup33100k_noise_white_5.00e-02 .pidx
# bunny100k_noise_white_1.00e-02 .curv
# star_smooth100k_ddist_minmax_layers .normals
# cylinder100k_ddist_minmax .xyz
# boxunion2100k_ddist_minmax_layers .normals
# column100k_noise_white_4.00e-02 .curv
# sheet_analytic100k_noise_white_5.00e-02 .curv
# bunny100k_ddist_minmax .pidx
# boxunion_uniform100k_ddist_minmax .normals
# galera100k_noise_white_2.00e-02 .curv
# armadillo100k .xyz
# armadillo100k_noise_brown_6.00e-02 .curv
# sphere_analytic100k .curv
# fandisk100k_noise_white_4.00e-02 .xyz
# star_smooth100k_noise_white_4.00e-02 .xyz
# bunny100k_noise_white_1.00e-02 .normals
# Liberty100k .normals
# pipe_curve100k_noise_white_3.00e-02 .curv
# sphere_analytic100k_noise_white_6.00e-02 .curv
# fandisk100k_noise_brown_1.00e-01 .xyz
# column100k_noise_white_4.00e-02 .normals
# boxunion2100k_noise_white_5.00e-02 .xyz
# cylinder_analytic100k_noise_white_5.00e-02 .xyz
# fandisk100k_noise_white_2.00e-02 .curv
# sphere100k .curv
# sheet_analytic100k_noise_white_1.00e-01 .xyz
# sphere_analytic100k_noise_white_3.00e-02 .curv
# tortuga100k_noise_white_1.00e-01 .xyz
# column_head100k_noise_white_1.00e-01 .curv
# Cup34100k_noise_white_2.00e-02 .curv
# cylinder100k_noise_white_3.00e-02 .xyz
# boxunion_uniform100k_noise_white_9.00e-02 .normals
# fandisk100k_noise_white_7.00e-02 .xyz
# Boxy_smooth100k_noise_white_4.00e-02 .xyz
# testset_med_noise .txt
# sheet_analytic100k_noise_white_4.00e-02 .normals
# tortuga100k_noise_white_8.00e-02 .normals
# cylinder_analytic100k_noise_white_4.00e-02 .curv
# tortuga100k_ddist_minmax_layers .curv
# fandisk100k_noise_white_8.00e-02 .normals
# Liberty100k_noise_white_5.00e-02 .curv
# pipe_curve100k_noise_white_1.00e-01 .normals
# star_sharp100k_noise_white_8.00e-02 .normals
# Boxy_smooth100k_noise_white_5.00e-02 .pidx
# column_head100k_noise_white_7.00e-02 .xyz
# star_smooth100k_noise_white_6.00e-02 .normals
# star_smooth100k_noise_white_1.00e-01 .normals
# dragon_xyzrgb100k_noise_white_1.00e-02 .xyz
# boxunion_uniform100k_noise_white_7.00e-02 .curv
# fandisk100k_ddist_minmax .xyz
# cylinder100k_noise_white_1.00e-02 .curv
# netsuke100k_noise_white_1.00e-02 .xyz
# flower100k_noise_white_4.00e-02 .xyz
# galera100k_noise_white_5.00e-02 .xyz
# cylinder_analytic100k_noise_white_1.00e-01 .normals
# Cup33100k_noise_white_2.00e-02 .curv
# star_sharp100k_noise_white_1.00e-02 .normals
# sheet_analytic100k .curv
# Cup33100k .pidx
# galera100k_noise_white_6.00e-02 .xyz
# fandisk100k_noise_white_4.00e-02 .normals
# boxunion2100k_noise_white_1.00e-02 .pidx
# pipe_curve100k_noise_white_9.00e-02 .xyz
# tortuga100k .normals
# boxunion2100k_ddist_minmax_layers .curv
# bunny100k_noise_brown_1.00e-01 .xyz
# column100k_noise_white_6.00e-02 .curv
# icosahedron100k_noise_white_7.00e-02 .curv
# galera100k_noise_white_5.00e-02 .pidx
# star_halfsmooth100k_noise_white_8.00e-02 .curv
# cylinder100k_noise_white_2.00e-02 .normals
# sheet_analytic100k_noise_white_8.00e-02 .curv
# Boxy_smooth100k_noise_white_1.00e-02 .xyz
# pipe100k_noise_white_6.00e-02 .xyz
# galera100k .normals
# boxunion_uniform100k_noise_brown_2.00e-02 .normals
# boxunion_uniform100k_noise_brown_4.00e-02 .curv
# star_smooth100k_noise_white_7.00e-02 .xyz
# armadillo100k_noise_brown_9.00e-02 .normals
# column_head100k_noise_white_5.00e-02 .xyz
# sheet_analytic100k_noise_white_1.00e-02 .xyz
# armadillo100k_noise_white_6.00e-02 .normals
# armadillo100k_noise_white_7.00e-02 .normals
# star_smooth100k_noise_white_6.00e-02 .curv
# armadillo100k_noise_white_1.00e-02 .pidx
# Boxy_smooth100k_noise_white_1.00e-01 .curv
# dragon_xyzrgb100k .normals
# pipe100k_ddist_minmax_layers .xyz
# dragon_xyzrgb100k_ddist_minmax .curv
# bunny100k_noise_white_4.00e-02 .xyz
# boxunion2100k .xyz
# netsuke100k_noise_white_5.00e-02 .normals
# fandisk100k_ddist_minmax .normals
# star_halfsmooth100k_ddist_minmax_layers .xyz
# boxunion2100k_noise_white_7.00e-02 .normals
# armadillo100k_noise_brown_5.00e-02 .xyz
# pipe100k_noise_white_7.00e-02 .xyz
# Boxy_smooth100k_noise_white_4.00e-02 .curv
# Cup33100k_noise_white_5.00e-02 .xyz
# sphere_analytic100k_noise_white_5.00e-02 .xyz
# Liberty100k_noise_white_5.00e-02 .xyz
# testset_low_noise .txt
# boxunion_uniform100k_noise_brown_3.00e-02 .curv
# pipe_curve100k_noise_white_4.00e-02 .curv
# armadillo100k_noise_white_1.00e-01 .pidx
# dragon_xyzrgb100k_noise_white_5.00e-02 .pidx
# pipe100k_noise_white_9.00e-02 .curv
# sphere100k_ddist_minmax .xyz
# star_halfsmooth100k .curv
# tortuga100k_noise_white_6.00e-02 .xyz
# fandisk100k_noise_white_9.00e-02 .xyz
# icosahedron100k_ddist_minmax .normals
# bunny100k_noise_brown_7.00e-02 .xyz
# Boxy_smooth100k_noise_white_1.00e-02 .normals
# Cup33100k .curv
# pipe100k_noise_white_4.00e-02 .curv
# bunny100k_noise_white_4.00e-02 .curv
# star_halfsmooth100k_noise_white_5.00e-02 .normals
# icosahedron100k_noise_white_9.00e-02 .normals
# Cup34100k_noise_white_1.00e-01 .xyz
# netsuke100k_ddist_minmax .xyz
# Liberty100k_noise_white_7.00e-02 .curv
# cylinder_analytic100k_noise_white_6.00e-02 .normals
# cylinder100k_noise_white_6.00e-02 .normals
# boxunion_uniform100k_noise_white_1.00e-02 .curv
# armadillo100k_noise_white_2.00e-02 .curv
# cylinder100k_noise_white_4.00e-02 .curv
# star_smooth100k_noise_white_2.00e-02 .xyz
# column_head100k_noise_white_1.00e-02 .xyz
# pipe_curve100k_ddist_minmax_layers .normals
# armadillo100k_noise_brown_9.00e-02 .curv
# netsuke100k_noise_white_1.00e-01 .normals
# Boxy_smooth100k_noise_white_1.00e-01 .normals
# Liberty100k_ddist_minmax .xyz
# boxunion_uniform100k_noise_brown_1.00e-02 .xyz
# boxunion_uniform100k_noise_brown_5.00e-02 .xyz
# flower100k_noise_white_3.00e-02 .normals
# Cup33100k_noise_white_1.00e-01 .curv
# Boxy_smooth100k_ddist_minmax .xyz
# Cup34100k_noise_white_3.00e-02 .xyz
# boxunion2100k .pidx
# pipe_curve100k_noise_white_1.00e-01 .curv
# cylinder_analytic100k_noise_white_1.00e-01 .pidx
# sphere_analytic100k_noise_white_8.00e-02 .normals
# fandisk100k_noise_white_8.00e-02 .xyz
# Boxy_smooth100k_ddist_minmax_layers .normals
# Boxy_smooth100k_noise_white_9.00e-02 .normals
# boxunion2100k_noise_white_2.00e-02 .normals
# Cup34100k_noise_white_1.00e-01 .curv
# cylinder100k_noise_white_6.00e-02 .xyz
# pipe100k_noise_white_1.00e-02 .normals
# Boxy_smooth100k_noise_white_8.00e-02 .normals
# Cup33100k_noise_white_1.00e-02 .curv
# flower100k .pidx
# boxunion2100k_ddist_minmax .pidx
# pipe100k_noise_white_5.00e-02 .curv
# star_sharp100k_noise_white_1.00e-02 .pidx
# cylinder100k_ddist_minmax_layers .normals
# Cup34100k_noise_white_5.00e-02 .normals
# Boxy_smooth100k_noise_white_2.00e-02 .normals
# sphere100k_noise_white_8.00e-02 .xyz
# sphere_analytic100k_noise_white_9.00e-02 .curv
# sphere_analytic100k .pidx
# pipe100k_noise_white_2.00e-02 .xyz
# Liberty100k_noise_white_4.00e-02 .normals
# star_sharp100k_noise_white_5.00e-02 .normals
# testset_all .txt
# column100k .xyz
# trainingset_no_noise .txt
# Liberty100k .curv
# boxunion2100k_noise_white_9.00e-02 .xyz
# galera100k_noise_white_1.00e-02 .curv
# Cup33100k_noise_white_1.00e-02 .pidx
# netsuke100k_noise_white_8.00e-02 .normals
# sheet_analytic100k_noise_white_5.00e-02 .normals
# star_sharp100k_ddist_minmax .xyz
# column100k_noise_white_8.00e-02 .curv
# dragon_xyzrgb100k_noise_white_4.00e-02 .xyz
# flower100k_noise_white_5.00e-02 .normals
# Cup34100k_noise_white_2.00e-02 .xyz
# pipe100k .normals
# column_head100k_noise_white_9.00e-02 .curv
# sheet_analytic100k_noise_white_1.00e-01 .normals
# boxunion2100k_noise_white_7.00e-02 .curv
# star_halfsmooth100k_ddist_minmax .pidx
# star_smooth100k_ddist_minmax .curv
# Cup33100k_noise_white_3.00e-02 .xyz
# star_smooth100k .pidx
# column_head100k_noise_white_8.00e-02 .xyz
# column_head100k_noise_white_7.00e-02 .normals
# bunny100k_ddist_minmax_layers .curv
# flower100k_noise_white_7.00e-02 .normals
# Liberty100k_ddist_minmax .normals
# boxunion2100k_noise_white_6.00e-02 .normals
# armadillo100k_noise_brown_2.00e-02 .xyz
# pipe_curve100k_noise_white_9.00e-02 .curv
# star_halfsmooth100k_noise_white_9.00e-02 .xyz
# dragon_xyzrgb100k_noise_white_9.00e-02 .xyz
# bunny100k .xyz
# bunny100k_noise_white_7.00e-02 .xyz
# star_halfsmooth100k_noise_white_1.00e-02 .normals
# dragon_xyzrgb100k_noise_white_1.00e-01 .curv
# sphere_analytic100k_noise_white_2.00e-02 .curv
# boxunion2100k_noise_white_4.00e-02 .normals
# column100k .pidx
# tortuga100k_noise_white_4.00e-02 .xyz
# Cup34100k .xyz
# netsuke100k_noise_white_1.00e-02 .normals
# star_smooth100k_noise_white_1.00e-01 .xyz
# dragon_xyzrgb100k_noise_white_8.00e-02 .curv
# column_head100k_noise_white_4.00e-02 .xyz
# boxunion2100k_noise_white_3.00e-02 .curv
# galera100k_ddist_minmax .curv
# cylinder_analytic100k .xyz
# bunny100k_noise_brown_4.00e-02 .normals
# column_head100k_ddist_minmax_layers .normals
# pipe100k_noise_white_9.00e-02 .xyz
# bunny100k_noise_brown_1.00e-01 .curv
# fandisk100k_noise_white_1.00e-01 .normals
# Boxy_smooth100k_ddist_minmax .pidx
# dragon_xyzrgb100k_noise_white_2.00e-02 .normals
# column100k_ddist_minmax .pidx
# armadillo100k_ddist_minmax_layers .normals
# fandisk100k_noise_brown_3.00e-02 .curv
# icosahedron100k_noise_white_1.00e-02 .xyz
# sphere100k_ddist_minmax_layers .normals
# bunny100k_noise_brown_1.00e-02 .xyz
# cylinder_analytic100k_noise_white_9.00e-02 .curv
# Boxy_smooth100k_ddist_minmax_layers .curv
# column100k_noise_white_5.00e-02 .normals
# Liberty100k_noise_white_1.00e-01 .pidx
# Liberty100k_noise_white_9.00e-02 .xyz
# star_halfsmooth100k_noise_white_2.00e-02 .xyz
# pipe_curve100k_noise_white_5.00e-02 .xyz
# boxunion_uniform100k_noise_white_9.00e-02 .curv
# pipe100k_noise_white_6.00e-02 .curv
# icosahedron100k_noise_white_5.00e-02 .normals
# fandisk100k_noise_white_9.00e-02 .normals
# fandisk100k_noise_white_8.00e-02 .curv
# sphere_analytic100k_noise_white_1.00e-01 .pidx
# pipe_curve100k_noise_white_8.00e-02 .curv
# sphere_analytic100k_noise_white_5.00e-02 .normals
# armadillo100k_noise_white_2.00e-02 .normals
# armadillo100k_noise_white_6.00e-02 .xyz
# cylinder_analytic100k_noise_white_1.00e-01 .curv
# column100k_noise_white_2.00e-02 .xyz
# pipe_curve100k_noise_white_1.00e-02 .curv
# icosahedron100k .curv
# pipe_curve100k_noise_white_8.00e-02 .xyz
# armadillo100k_ddist_minmax_layers .xyz
# fandisk100k_noise_brown_6.00e-02 .curv
# Liberty100k_ddist_minmax_layers .pidx
# galera100k_noise_white_3.00e-02 .curv
# Cup34100k_noise_white_5.00e-02 .xyz
# bunny100k .pidx
# sphere100k_noise_white_1.00e-01 .normals
# armadillo100k_noise_white_9.00e-02 .curv
# armadillo100k_noise_brown_7.00e-02 .curv
# pipe_curve100k_noise_white_1.00e-02 .pidx
# armadillo100k_ddist_minmax_layers .curv
# netsuke100k_noise_white_6.00e-02 .curv
# galera100k_noise_white_9.00e-02 .curv
# armadillo100k_noise_white_1.00e-01 .curv
# column100k_noise_white_1.00e-02 .xyz
# cylinder_analytic100k_noise_white_5.00e-02 .normals
# column100k_noise_white_4.00e-02 .xyz
# cylinder_analytic100k_noise_white_3.00e-02 .curv
# pipe100k_noise_white_7.00e-02 .curv
# column_head100k_noise_white_1.00e-01 .normals
# fandisk100k_noise_white_1.00e-01 .curv
# pipe100k_ddist_minmax .normals
# bunny100k_noise_white_1.00e-01 .xyz
# tortuga100k_noise_white_5.00e-02 .normals
# fandisk100k_noise_white_6.00e-02 .normals
# bunny100k_noise_white_2.00e-02 .curv
# armadillo100k_noise_white_5.00e-02 .pidx
# column100k_ddist_minmax_layers .pidx
# boxunion2100k_noise_white_1.00e-01 .pidx
# boxunion_uniform100k_noise_white_1.00e-01 .xyz
# boxunion_uniform100k_noise_white_2.00e-02 .xyz
# cylinder100k_noise_white_3.00e-02 .normals
# validationset_whitenoise .txt
# bunny100k .normals
# flower100k_noise_white_2.00e-02 .curv
# Liberty100k_noise_white_8.00e-02 .curv
# star_halfsmooth100k_noise_white_3.00e-02 .normals
# Cup34100k_noise_white_4.00e-02 .xyz
# pipe_curve100k_noise_white_4.00e-02 .xyz
# star_sharp100k_noise_white_2.00e-02 .normals
# dragon_xyzrgb100k_noise_white_3.00e-02 .curv
# Liberty100k .pidx
# column100k_noise_white_3.00e-02 .xyz
# column100k .normals
# galera100k_noise_white_1.00e-01 .normals
# star_sharp100k_ddist_minmax .normals
# Liberty100k_noise_white_1.00e-02 .pidx
# bunny100k_noise_brown_9.00e-02 .xyz
# sphere_analytic100k_noise_white_9.00e-02 .xyz
# star_smooth100k .curv
# Liberty100k_noise_white_1.00e-02 .curv
# pipe100k_noise_white_5.00e-02 .normals
# Liberty100k_noise_white_5.00e-02 .pidx
# cylinder_analytic100k_noise_white_3.00e-02 .xyz
# tortuga100k_ddist_minmax_layers .xyz
# boxunion_uniform100k_noise_white_6.00e-02 .normals
# bunny100k_noise_brown_2.00e-02 .xyz
# boxunion_uniform100k_noise_white_2.00e-02 .curv
# fandisk100k_noise_white_1.00e-02 .xyz
# Cup34100k_noise_white_1.00e-02 .normals
# boxunion_uniform100k_noise_white_3.00e-02 .xyz
# Cup34100k_noise_white_1.00e-02 .xyz
# armadillo100k_noise_brown_5.00e-02 .normals
# fandisk100k_noise_brown_9.00e-02 .curv
# tortuga100k .curv
# sphere_analytic100k_noise_white_6.00e-02 .normals
# sphere_analytic100k_noise_white_1.00e-01 .curv
# cylinder100k_noise_white_7.00e-02 .normals
# flower100k_noise_white_1.00e-02 .xyz
# flower100k_ddist_minmax_layers .curv
# boxunion2100k_noise_white_6.00e-02 .curv
# column_head100k_noise_white_2.00e-02 .curv
# icosahedron100k_ddist_minmax .pidx
# boxunion_uniform100k_noise_white_1.00e-02 .pidx
# pipe100k_noise_white_9.00e-02 .normals
# Boxy_smooth100k_noise_white_5.00e-02 .curv
# netsuke100k .pidx
# tortuga100k_ddist_minmax .curv
# pipe_curve100k .xyz
# trainingset_whitenoise .txt
# star_smooth100k_noise_white_5.00e-02 .curv
# flower100k_noise_white_1.00e-01 .curv
# Cup33100k_noise_white_7.00e-02 .normals
# Cup34100k_noise_white_9.00e-02 .curv
# flower100k_noise_white_1.00e-01 .xyz
# armadillo100k_noise_white_4.00e-02 .xyz
# star_smooth100k_noise_white_9.00e-02 .xyz
# sheet_analytic100k_noise_white_2.00e-02 .normals
# bunny100k_noise_white_5.00e-02 .normals
# bunny100k_noise_white_7.00e-02 .curv
# pipe100k_ddist_minmax_layers .curv
# star_smooth100k_noise_white_9.00e-02 .normals
# star_halfsmooth100k_ddist_minmax_layers .pidx
# tortuga100k_noise_white_6.00e-02 .curv
# bunny100k_noise_brown_1.00e-01 .normals
# cylinder100k_noise_white_8.00e-02 .normals
# star_smooth100k_noise_white_1.00e-02 .xyz
# boxunion_uniform100k_noise_brown_6.00e-02 .curv
# bunny100k_noise_white_6.00e-02 .curv
# Cup33100k_ddist_minmax_layers .normals
# star_halfsmooth100k_noise_white_3.00e-02 .curv
# pipe_curve100k_noise_white_3.00e-02 .normals
# cylinder_analytic100k_noise_white_5.00e-02 .curv
# column_head100k_ddist_minmax .pidx
# sheet_analytic100k_noise_white_1.00e-02 .normals
# dragon_xyzrgb100k_ddist_minmax_layers .curv
# sphere_analytic100k_noise_white_1.00e-01 .normals
# column100k_noise_white_2.00e-02 .curv
# sphere_analytic100k_noise_white_1.00e-02 .curv
# armadillo100k_noise_brown_2.00e-02 .curv
# fandisk100k_ddist_minmax .pidx
# star_halfsmooth100k_ddist_minmax .curv
# Cup34100k_noise_white_6.00e-02 .curv
# flower100k_noise_white_6.00e-02 .curv
# boxunion_uniform100k_ddist_minmax .curv
# star_halfsmooth100k_noise_white_1.00e-01 .pidx
# fandisk100k_noise_brown_6.00e-02 .normals
# cylinder100k_noise_white_8.00e-02 .curv
# icosahedron100k_noise_white_8.00e-02 .xyz
# cylinder100k_ddist_minmax_layers .curv
# Cup33100k_noise_white_6.00e-02 .curv
# netsuke100k_noise_white_7.00e-02 .curv
# galera100k_noise_white_7.00e-02 .xyz
# armadillo100k_noise_brown_7.00e-02 .normals
# flower100k_noise_white_1.00e-02 .curv
# star_sharp100k_noise_white_3.00e-02 .curv
# fandisk100k_noise_white_5.00e-02 .xyz
# sphere_analytic100k_noise_white_9.00e-02 .normals
# Cup33100k_noise_white_5.00e-02 .curv
# sheet_analytic100k_noise_white_8.00e-02 .normals
# pipe_curve100k_noise_white_7.00e-02 .xyz
# flower100k_noise_white_8.00e-02 .normals
# star_halfsmooth100k_noise_white_1.00e-01 .xyz
# galera100k_noise_white_4.00e-02 .xyz
# bunny100k_noise_white_9.00e-02 .xyz
# dragon_xyzrgb100k_noise_white_9.00e-02 .normals
# icosahedron100k_noise_white_3.00e-02 .normals
# boxunion2100k_noise_white_2.00e-02 .xyz
# column100k_ddist_minmax_layers .curv
# star_smooth100k_noise_white_4.00e-02 .curv
# bunny100k_noise_brown_5.00e-02 .normals
# galera100k_ddist_minmax_layers .normals
# boxunion_uniform100k_noise_white_4.00e-02 .curv
# icosahedron100k_noise_white_6.00e-02 .normals
# flower100k .xyz
# cylinder100k_noise_white_1.00e-02 .pidx
# netsuke100k_noise_white_3.00e-02 .xyz
# cylinder100k_noise_white_5.00e-02 .xyz
# star_smooth100k_noise_white_3.00e-02 .xyz
# boxunion_uniform100k_noise_white_6.00e-02 .curv
# galera100k_noise_white_8.00e-02 .curv
# Boxy_smooth100k_noise_white_1.00e-01 .pidx
# bunny100k_noise_white_1.00e-01 .normals
# pipe100k .xyz
# Cup33100k_noise_white_8.00e-02 .curv
# cylinder100k_ddist_minmax .pidx
# bunny100k_noise_white_8.00e-02 .curv
# flower100k_noise_white_7.00e-02 .curv
# dragon_xyzrgb100k_noise_white_7.00e-02 .normals
# cylinder100k_ddist_minmax_layers .pidx
# netsuke100k_noise_white_5.00e-02 .curv
# star_halfsmooth100k_noise_white_3.00e-02 .xyz
# nyu .txt
# Boxy_smooth100k_noise_white_3.00e-02 .normals
# tortuga100k_noise_white_5.00e-02 .xyz
# star_sharp100k_noise_white_1.00e-02 .xyz
# bunny100k_noise_white_6.00e-02 .xyz
# sheet_analytic100k_noise_white_7.00e-02 .curv
# Boxy_smooth100k_ddist_minmax_layers .pidx
# boxunion_uniform100k_noise_brown_2.00e-02 .curv
# download_pclouds .py
# sphere_analytic100k_noise_white_2.00e-02 .normals
# armadillo100k_noise_white_8.00e-02 .curv
# pipe_curve100k_ddist_minmax .normals
# star_sharp100k_ddist_minmax_layers .pidx
# cylinder_analytic100k .normals
# star_halfsmooth100k .normals
# flower100k_ddist_minmax .curv
# cylinder100k_noise_white_4.00e-02 .xyz
# column_head100k .pidx
# pipe100k_ddist_minmax_layers .normals
# Cup34100k_noise_white_9.00e-02 .xyz
# star_halfsmooth100k_noise_white_9.00e-02 .curv
# sheet_analytic100k_noise_white_1.00e-01 .pidx
# flower100k_ddist_minmax .xyz
# Liberty100k_ddist_minmax_layers .curv
# star_sharp100k_noise_white_7.00e-02 .xyz
# sphere100k_ddist_minmax .curv
# dragon_xyzrgb100k_ddist_minmax .normals
# icosahedron100k_noise_white_4.00e-02 .normals
# galera100k_noise_white_2.00e-02 .normals
# sheet_analytic100k_noise_white_5.00e-02 .pidx
# armadillo100k_noise_white_1.00e-02 .xyz
# pipe_curve100k_noise_white_7.00e-02 .curv
# tortuga100k_noise_white_1.00e-01 .curv
# column100k_noise_white_3.00e-02 .normals
# cylinder_analytic100k_noise_white_7.00e-02 .xyz
# flower100k_noise_white_8.00e-02 .curv
# star_sharp100k_noise_white_4.00e-02 .curv
# cylinder100k .pidx
# Cup34100k_noise_white_1.00e-01 .pidx
# armadillo100k_noise_white_3.00e-02 .normals
# fandisk100k_noise_brown_9.00e-02 .xyz
# cylinder_analytic100k_noise_white_8.00e-02 .normals
# armadillo100k_noise_white_4.00e-02 .normals
# column100k_noise_white_8.00e-02 .normals
# star_smooth100k_noise_white_1.00e-02 .curv
# netsuke100k_noise_white_1.00e-02 .curv
# cylinder_analytic100k_noise_white_7.00e-02 .normals
# bunny100k_noise_brown_3.00e-02 .normals
# flower100k_noise_white_5.00e-02 .curv
# cylinder100k_noise_white_5.00e-02 .curv
# cylinder_analytic100k_noise_white_8.00e-02 .xyz
# Liberty100k_noise_white_8.00e-02 .xyz
# pipe_curve100k .curv
# pipe100k_noise_white_5.00e-02 .xyz
# star_halfsmooth100k_noise_white_5.00e-02 .pidx
# dragon_xyzrgb100k_noise_white_6.00e-02 .normals
# cylinder100k_noise_white_3.00e-02 .curv
# bunny100k_noise_brown_2.00e-02 .normals
# column_head100k_noise_white_1.00e-02 .normals
# cylinder_analytic100k_noise_white_4.00e-02 .xyz
# star_halfsmooth100k_noise_white_9.00e-02 .normals
# armadillo100k_noise_white_4.00e-02 .curv
# icosahedron100k_noise_white_1.00e-02 .curv
# galera100k_ddist_minmax_layers .xyz
# star_halfsmooth100k_noise_white_6.00e-02 .normals
# bunny100k_ddist_minmax .curv
# armadillo100k_noise_white_3.00e-02 .xyz
# boxunion2100k_noise_white_1.00e-02 .xyz
# armadillo100k_noise_white_7.00e-02 .xyz
# netsuke100k_noise_white_3.00e-02 .normals
# sphere100k .xyz
# boxunion_uniform100k_noise_white_8.00e-02 .normals
# bunny100k_noise_white_1.00e-02 .xyz
# netsuke100k_noise_white_1.00e-02 .pidx
# boxunion2100k .normals
# bunny100k_noise_brown_9.00e-02 .normals
# pipe_curve100k_noise_white_1.00e-02 .xyz
# column_head100k .xyz
# flower100k .curv
# cylinder_analytic100k_noise_white_6.00e-02 .xyz
# pipe100k .pidx
# column100k_ddist_minmax .xyz
# fandisk100k_noise_brown_6.00e-02 .xyz
# boxunion_uniform100k_noise_white_1.00e-01 .curv
# bunny100k_noise_brown_3.00e-02 .curv
# cylinder100k .curv
# tortuga100k_noise_white_2.00e-02 .xyz
# cylinder_analytic100k_noise_white_1.00e-01 .xyz
# bunny100k_noise_white_3.00e-02 .xyz
# bunny100k_noise_white_3.00e-02 .curv
# column_head100k_noise_white_1.00e-01 .xyz
# cylinder100k_noise_white_9.00e-02 .normals
# flower100k_noise_white_1.00e-01 .pidx
# sheet_analytic100k_noise_white_6.00e-02 .normals
# pipe100k_noise_white_3.00e-02 .normals
# fandisk100k_noise_white_1.00e-02 .curv
# Liberty100k_noise_white_2.00e-02 .curv
# column100k_ddist_minmax_layers .normals
# star_smooth100k_noise_white_5.00e-02 .normals
# column100k_noise_white_1.00e-01 .normals
# boxunion_uniform100k .pidx
# galera100k_noise_white_1.00e-02 .xyz
# galera100k_noise_white_5.00e-02 .curv
# Boxy_smooth100k_noise_white_1.00e-01 .xyz
# star_halfsmooth100k_noise_white_1.00e-02 .pidx
# netsuke100k_ddist_minmax_layers .pidx
# fandisk100k_ddist_minmax_layers .xyz
# fandisk100k_noise_brown_4.00e-02 .xyz
# netsuke100k_noise_white_9.00e-02 .curv
# sheet_analytic100k_noise_white_1.00e-02 .curv
# flower100k_noise_white_7.00e-02 .xyz
# star_smooth100k_ddist_minmax_layers .curv
# bunny100k_noise_white_6.00e-02 .normals
# Cup33100k_ddist_minmax_layers .curv
# netsuke100k_noise_white_4.00e-02 .curv
# star_sharp100k_noise_white_6.00e-02 .curv
# armadillo100k_noise_brown_4.00e-02 .normals
# galera100k_noise_white_4.00e-02 .normals
# star_sharp100k_noise_white_4.00e-02 .normals
# Liberty100k_ddist_minmax .curv
# fandisk100k_noise_brown_7.00e-02 .normals
# star_halfsmooth100k_noise_white_7.00e-02 .curv
# Cup34100k_noise_white_5.00e-02 .curv
# boxunion_uniform100k_noise_brown_4.00e-02 .xyz
# sphere100k_noise_white_3.00e-02 .curv
# column_head100k_noise_white_3.00e-02 .curv
# flower100k_noise_white_6.00e-02 .xyz
# Cup34100k .curv
# star_smooth100k_ddist_minmax .xyz
# armadillo100k_noise_brown_1.00e-02 .curv
# dragon_xyzrgb100k_noise_white_4.00e-02 .normals
# boxunion_uniform100k_noise_brown_5.00e-02 .curv
# boxunion2100k_noise_white_9.00e-02 .normals
# fandisk100k_noise_white_7.00e-02 .curv
# flower100k_noise_white_2.00e-02 .xyz
# pipe_curve100k_ddist_minmax .curv
# dragon_xyzrgb100k_noise_white_1.00e-02 .normals
# sphere_analytic100k_noise_white_7.00e-02 .normals
# armadillo100k_noise_brown_5.00e-02 .curv
# sphere100k_ddist_minmax_layers .pidx
# Cup34100k_noise_white_1.00e-01 .normals
# sheet_analytic100k_noise_white_8.00e-02 .xyz
# sphere100k_noise_white_2.00e-02 .xyz
# Liberty100k_noise_white_4.00e-02 .curv
# bunny100k_noise_white_2.00e-02 .normals
# sheet_analytic100k_noise_white_5.00e-02 .xyz
# Liberty100k_noise_white_1.00e-02 .normals
# dragon_xyzrgb100k_noise_white_3.00e-02 .normals
# fandisk100k_noise_brown_7.00e-02 .xyz
# dragon_xyzrgb100k_noise_white_6.00e-02 .xyz
# tortuga100k_noise_white_8.00e-02 .curv
# sphere100k_noise_white_2.00e-02 .curv
# boxunion_uniform100k_ddist_minmax .pidx
# galera100k_noise_white_1.00e-02 .normals
# fandisk100k .xyz
# boxunion_uniform100k_ddist_minmax .xyz
# Cup33100k_ddist_minmax .curv
# icosahedron100k_noise_white_5.00e-02 .curv
# Cup34100k_noise_white_4.00e-02 .normals
# pipe100k_noise_white_6.00e-02 .normals
# icosahedron100k_noise_white_1.00e-01 .curv
# netsuke100k_noise_white_9.00e-02 .normals
# Cup34100k_ddist_minmax .normals
# armadillo100k .normals
# pipe_curve100k_noise_white_6.00e-02 .xyz
# fandisk100k_noise_brown_1.00e-02 .xyz
# tortuga100k_noise_white_7.00e-02 .normals
# tortuga100k_noise_white_5.00e-02 .curv
# pipe100k_noise_white_5.00e-02 .pidx
# cylinder_analytic100k_noise_white_5.00e-02 .pidx
# sphere100k_noise_white_5.00e-02 .normals
# icosahedron100k_noise_white_5.00e-02 .xyz
# icosahedron100k .xyz
# sphere100k_noise_white_3.00e-02 .normals
# pipe_curve100k_ddist_minmax_layers .curv
# fandisk100k_noise_brown_5.00e-02 .normals
# dragon_xyzrgb100k_noise_white_4.00e-02 .curv
# fandisk100k_noise_brown_1.00e-01 .normals
# boxunion_uniform100k_noise_white_1.00e-02 .xyz
# star_sharp100k_noise_white_6.00e-02 .xyz
# column_head100k_ddist_minmax_layers .curv
# bunny100k_noise_brown_8.00e-02 .normals
# Liberty100k_ddist_minmax_layers .normals
# boxunion2100k_noise_white_1.00e-02 .curv
# icosahedron100k_ddist_minmax .xyz
# sphere100k_noise_white_2.00e-02 .normals
# boxunion2100k_ddist_minmax .normals
# Cup34100k_noise_white_8.00e-02 .curv
# Cup34100k_noise_white_6.00e-02 .xyz
# cylinder100k_noise_white_4.00e-02 .normals
# bunny100k_noise_brown_9.00e-02 .curv
# icosahedron100k .normals
# galera100k_noise_white_3.00e-02 .xyz
# star_smooth100k_noise_white_1.00e-02 .pidx
# armadillo100k_noise_brown_8.00e-02 .xyz
# Liberty100k_noise_white_8.00e-02 .normals
# boxunion_uniform100k_noise_white_7.00e-02 .xyz
# sphere_analytic100k_noise_white_1.00e-02 .xyz
# column_head100k_noise_white_1.00e-01 .pidx
# dragon_xyzrgb100k_noise_white_9.00e-02 .curv
# armadillo100k_ddist_minmax .normals
# tortuga100k_noise_white_7.00e-02 .xyz
# Liberty100k_noise_white_3.00e-02 .curv
# cylinder_analytic100k .pidx
# tortuga100k_noise_white_1.00e-02 .curv
# pipe100k_noise_white_4.00e-02 .normals
# flower100k_ddist_minmax_layers .normals
# dragon_xyzrgb100k_noise_white_1.00e-02 .pidx
# testset_vardensity_gradient .txt
# star_sharp100k_noise_white_1.00e-01 .pidx
# armadillo100k_noise_brown_6.00e-02 .normals
# fandisk100k .normals
# pipe_curve100k_noise_white_8.00e-02 .normals
# bunny100k_noise_white_9.00e-02 .normals
# Boxy_smooth100k_noise_white_8.00e-02 .curv
# icosahedron100k_noise_white_1.00e-01 .normals
# galera100k_noise_white_1.00e-01 .xyz
# dragon_xyzrgb100k_noise_white_5.00e-02 .curv
# boxunion_uniform100k_noise_white_1.00e-02 .normals
# boxunion_uniform100k .xyz
# armadillo100k_ddist_minmax .curv
# fandisk100k_noise_white_2.00e-02 .normals
# dragon_xyzrgb100k_ddist_minmax .xyz
# Liberty100k_noise_white_5.00e-02 .normals
# boxunion2100k_noise_white_3.00e-02 .normals
# fandisk100k_noise_white_1.00e-02 .pidx
# column_head100k_noise_white_5.00e-02 .curv
# icosahedron100k_ddist_minmax_layers .xyz
# flower100k_noise_white_3.00e-02 .curv
# Cup34100k_ddist_minmax .curv
# column_head100k_noise_white_5.00e-02 .normals
# Cup33100k_noise_white_5.00e-02 .normals
# bunny100k_noise_brown_2.00e-02 .curv
# dragon_xyzrgb100k_ddist_minmax_layers .xyz
# Liberty100k_noise_white_3.00e-02 .xyz
# armadillo100k_noise_brown_2.00e-02 .normals
# column100k_noise_white_5.00e-02 .curv
# tortuga100k_noise_white_8.00e-02 .xyz
# boxunion_uniform100k_noise_brown_1.00e-02 .normals
# sphere_analytic100k_noise_white_4.00e-02 .curv
# column100k_noise_white_5.00e-02 .pidx
# star_sharp100k_ddist_minmax_layers .normals
# star_smooth100k_noise_white_2.00e-02 .curv
# Boxy_smooth100k_noise_white_9.00e-02 .xyz
# boxunion2100k_noise_white_1.00e-01 .xyz
# boxunion_uniform100k_noise_white_1.00e-01 .pidx
# boxunion_uniform100k_noise_white_9.00e-02 .xyz
# flower100k_noise_white_5.00e-02 .pidx
# boxunion_uniform100k_noise_white_7.00e-02 .normals
# trainingset_vardensity .txt
# cylinder100k_noise_white_8.00e-02 .xyz
# tortuga100k_noise_white_9.00e-02 .xyz
# nyu_4 .xyz
# sphere100k_noise_white_4.00e-02 .curv
# sphere100k_ddist_minmax .pidx
# Cup34100k_ddist_minmax_layers .xyz
# flower100k_noise_white_6.00e-02 .normals
# cylinder_analytic100k_noise_white_2.00e-02 .normals
# column_head100k_noise_white_4.00e-02 .normals
# tortuga100k_noise_white_4.00e-02 .normals
# dragon_xyzrgb100k_noise_white_6.00e-02 .curv
# tortuga100k_ddist_minmax .xyz
# fandisk100k_ddist_minmax_layers .curv
# star_halfsmooth100k_ddist_minmax_layers .curv
# Cup33100k_noise_white_2.00e-02 .normals
# icosahedron100k_noise_white_1.00e-01 .pidx
# sphere100k_noise_white_6.00e-02 .normals
# armadillo100k_noise_white_6.00e-02 .curv
# flower100k_noise_white_1.00e-02 .normals
# star_smooth100k_noise_white_8.00e-02 .curv
# armadillo100k_ddist_minmax_layers .pidx
# galera100k_ddist_minmax_layers .pidx
# column100k_ddist_minmax_layers .xyz
# column_head100k_noise_white_3.00e-02 .xyz
# star_halfsmooth100k .xyz
# galera100k_noise_white_9.00e-02 .xyz
# bunny100k_noise_brown_5.00e-02 .xyz
# dragon_xyzrgb100k_noise_white_8.00e-02 .normals
# Boxy_smooth100k_ddist_minmax .normals
# cylinder100k_noise_white_1.00e-02 .xyz
# cylinder100k_ddist_minmax .curv
# sphere100k_noise_white_9.00e-02 .xyz
# dragon_xyzrgb100k_noise_white_3.00e-02 .xyz
# Cup33100k_ddist_minmax_layers .xyz
# Cup33100k_noise_white_2.00e-02 .xyz
# sphere100k_noise_white_8.00e-02 .normals
# armadillo100k_noise_white_9.00e-02 .normals

# %%
import resource

# Get the maximum resident set size in kilobytes
max_memory_kb = resource.getrusage(resource.RUSAGE_SELF).ru_maxrss

# Convert kilobytes to gigabytes
max_memory_gb = max_memory_kb / (1024 * 1024)

print(f"Maximum memory usage: {max_memory_gb:.2f} GB")
# Out:
# Maximum memory usage: 2.26 GB

# %%
#kill kernel
import os
os._exit(00)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os
import numpy as np
from natsort import natsorted
from glob import glob

def load_pcds(path):
    files = glob(os.path.join(path, "*.xyz"))
    print (files)
    # pcds = np.array([np.loadtxt(file) for file in files])
    # return pcds
x = load_pcds("pclouds")
# Out:
# ['pclouds/armadillo100k_noise_white_8.00e-02.xyz', 'pclouds/fandisk100k_noise_brown_5.00e-02.xyz', 'pclouds/sphere_analytic100k_noise_white_8.00e-02.xyz', 'pclouds/boxunion2100k_noise_white_8.00e-02.xyz', 'pclouds/pipe100k_ddist_minmax.xyz', 'pclouds/flower100k_noise_white_9.00e-02.xyz', 'pclouds/Liberty100k_noise_white_1.00e-01.xyz', 'pclouds/netsuke100k_ddist_minmax_layers.xyz', 'pclouds/boxunion2100k_ddist_minmax.xyz', 'pclouds/sphere100k_noise_white_1.00e-01.xyz', 'pclouds/sphere_analytic100k_noise_white_3.00e-02.xyz', 'pclouds/sphere_analytic100k.xyz', 'pclouds/armadillo100k_noise_brown_1.00e-02.xyz', 'pclouds/cylinder_analytic100k_noise_white_2.00e-02.xyz', 'pclouds/icosahedron100k_noise_white_7.00e-02.xyz', 'pclouds/armadillo100k_noise_brown_4.00e-02.xyz', 'pclouds/icosahedron100k_noise_white_9.00e-02.xyz', 'pclouds/column_head100k_ddist_minmax_layers.xyz', 'pclouds/cylinder100k_ddist_minmax_layers.xyz', 'pclouds/Cup33100k_noise_white_1.00e-02.xyz', 'pclouds/netsuke100k_noise_white_5.00e-02.xyz', 'pclouds/bunny100k_noise_white_5.00e-02.xyz', 'pclouds/cylinder100k_noise_white_7.00e-02.xyz', 'pclouds/nyu_4_whitenoise.xyz', 'pclouds/pipe_curve100k_ddist_minmax.xyz', 'pclouds/pipe_curve100k_noise_white_3.00e-02.xyz', 'pclouds/sphere100k_noise_white_4.00e-02.xyz', 'pclouds/armadillo100k_noise_brown_7.00e-02.xyz', 'pclouds/Cup34100k_noise_white_7.00e-02.xyz', 'pclouds/star_sharp100k_noise_white_2.00e-02.xyz', 'pclouds/star_sharp100k.xyz', 'pclouds/column_head100k_noise_white_2.00e-02.xyz', 'pclouds/star_smooth100k_noise_white_5.00e-02.xyz', 'pclouds/sphere100k_noise_white_6.00e-02.xyz', 'pclouds/Cup34100k_ddist_minmax.xyz', 'pclouds/bunny100k_noise_brown_3.00e-02.xyz', 'pclouds/netsuke100k_noise_white_4.00e-02.xyz', 'pclouds/star_smooth100k_noise_white_8.00e-02.xyz', 'pclouds/pipe100k_noise_white_1.00e-01.xyz', 'pclouds/column_head100k_noise_white_6.00e-02.xyz', 'pclouds/icosahedron100k_noise_white_2.00e-02.xyz', 'pclouds/cylinder100k_noise_white_9.00e-02.xyz', 'pclouds/Boxy_smooth100k_ddist_minmax_layers.xyz', 'pclouds/Liberty100k_ddist_minmax_layers.xyz', 'pclouds/boxunion_uniform100k_noise_white_6.00e-02.xyz', 'pclouds/Liberty100k_noise_white_7.00e-02.xyz', 'pclouds/Cup33100k_noise_white_6.00e-02.xyz', 'pclouds/star_sharp100k_noise_white_1.00e-01.xyz', 'pclouds/boxunion2100k_noise_white_3.00e-02.xyz', 'pclouds/pipe_curve100k_noise_white_1.00e-01.xyz', 'pclouds/boxunion_uniform100k_noise_white_8.00e-02.xyz', 'pclouds/pipe_curve100k_noise_white_2.00e-02.xyz', 'pclouds/armadillo100k_noise_brown_3.00e-02.xyz', 'pclouds/boxunion2100k_ddist_minmax_layers.xyz', 'pclouds/fandisk100k_noise_white_1.00e-01.xyz', 'pclouds/star_halfsmooth100k_noise_white_8.00e-02.xyz', 'pclouds/tortuga100k_noise_white_1.00e-02.xyz', 'pclouds/armadillo100k_noise_white_5.00e-02.xyz', 'pclouds/sphere_analytic100k_noise_white_2.00e-02.xyz', 'pclouds/armadillo100k_noise_brown_9.00e-02.xyz', 'pclouds/star_smooth100k_ddist_minmax_layers.xyz', 'pclouds/fandisk100k_noise_brown_2.00e-02.xyz', 'pclouds/sheet_analytic100k.xyz', 'pclouds/Boxy_smooth100k_noise_white_2.00e-02.xyz', 'pclouds/bunny100k_ddist_minmax_layers.xyz', 'pclouds/column100k_noise_white_9.00e-02.xyz', 'pclouds/sheet_analytic100k_noise_white_2.00e-02.xyz', 'pclouds/boxunion_uniform100k_noise_brown_6.00e-02.xyz', 'pclouds/flower100k_noise_white_5.00e-02.xyz', 'pclouds/fandisk100k_noise_brown_3.00e-02.xyz', 'pclouds/pipe100k_noise_white_1.00e-02.xyz', 'pclouds/bunny100k_noise_brown_4.00e-02.xyz', 'pclouds/tortuga100k.xyz', 'pclouds/sphere100k_noise_white_1.00e-02.xyz', 'pclouds/column_head100k_noise_white_9.00e-02.xyz', 'pclouds/icosahedron100k_noise_white_1.00e-01.xyz', 'pclouds/boxunion2100k_noise_white_7.00e-02.xyz', 'pclouds/column100k_noise_white_5.00e-02.xyz', 'pclouds/star_halfsmooth100k_noise_white_5.00e-02.xyz', 'pclouds/icosahedron100k_noise_white_3.00e-02.xyz', 'pclouds/boxunion_uniform100k_noise_white_5.00e-02.xyz', 'pclouds/sphere_analytic100k_noise_white_4.00e-02.xyz', 'pclouds/tortuga ...

# %%
import os
from natsort import natsorted
import glob

# Define the folder path
pc_folder_path = 'pclouds'  # Change this to the actual path

# Find all file paths ending with .xyz
xyz_files = natsorted(glob.glob(os.path.join(pc_folder_path, '*.xyz')))

# Find all file paths ending with .normals
normals_files = natsorted(glob.glob(os.path.join(pc_folder_path, '*.normals')))

print(len(xyz_files), len(normals_files))

# Print or use the results as needed
# print("XYZ Files:")
# for xyz_file in xyz_files:
#     print(xyz_file)

# print("\nNormals Files:")
# for normals_file in normals_files:
#     print(normals_file)
# Out:
# 383 381

# %%
c=0
ref_xyz = []
ref_normals = []
for xyz,norm in zip(xyz_files, normals_files):
    xyz_name,_ = os.path.splitext(xyz)
    norm_name,_ = os.path.splitext(norm)
    if f"{xyz_name}.normals" not in normals_files or f"{norm_name}.xyz" not in xyz_files:
        print(xyz_name, norm_name)
        c=c+1
        continue
    else:
        ref_xyz.append(xyz)
        ref_normals.append(norm)
    # print(xyz_name, norm_name)
    # if xyz_name != norm_name:
    #     c=c+1
    #     print(xyz_name, norm_name)
print(c)
# Out:
# pclouds/nyu_4 pclouds/pipe100k
# pclouds/nyu_4_whitenoise pclouds/pipe100k_ddist_minmax
# 2

# %%
print("pclouds/pipe100k_ddist_minmax_layers.xyz" in ref_xyz)
# Out:
# True

# %%
len(ref_normals)
# Out:
# 379

# %%
ref_xyz = natsorted(ref_xyz)
ref_normals = natsorted(ref_normals)
len(ref_xyz)
# Out:
# 379

# %%
c=0

for xyz,norm in zip(ref_xyz, ref_normals):
    xyz_name,_ = os.path.splitext(xyz)
    norm_name,_ = os.path.splitext(norm)
    # print(xyz_name, norm_name)
    if xyz_name != norm_name:
        c=c+1
        print(xyz_name, norm_name)
print(c)
# Out:
# pclouds/pipe100k pclouds/pipe100k_ddist_minmax_layers
# pclouds/pipe100k_ddist_minmax pclouds/pipe100k_noise_white_1.00e-01
# pclouds/pipe100k_ddist_minmax_layers pclouds/pipe100k_noise_white_1.00e-02
# pclouds/pipe100k_noise_white_1.00e-01 pclouds/pipe100k_noise_white_2.00e-02
# pclouds/pipe100k_noise_white_1.00e-02 pclouds/pipe100k_noise_white_3.00e-02
# pclouds/pipe100k_noise_white_2.00e-02 pclouds/pipe100k_noise_white_4.00e-02
# pclouds/pipe100k_noise_white_3.00e-02 pclouds/pipe100k_noise_white_5.00e-02
# pclouds/pipe100k_noise_white_4.00e-02 pclouds/pipe100k_noise_white_6.00e-02
# pclouds/pipe100k_noise_white_5.00e-02 pclouds/pipe100k_noise_white_7.00e-02
# pclouds/pipe100k_noise_white_6.00e-02 pclouds/pipe100k_noise_white_8.00e-02
# pclouds/pipe100k_noise_white_7.00e-02 pclouds/pipe100k_noise_white_9.00e-02
# pclouds/pipe100k_noise_white_8.00e-02 pclouds/pipe_curve100k
# pclouds/pipe100k_noise_white_9.00e-02 pclouds/pipe_curve100k_ddist_minmax
# pclouds/pipe_curve100k pclouds/pipe_curve100k_ddist_minmax_layers
# pclouds/pipe_curve100k_ddist_minmax pclouds/pipe_curve100k_noise_white_1.00e-01
# pclouds/pipe_curve100k_ddist_minmax_layers pclouds/pipe_curve100k_noise_white_1.00e-02
# pclouds/pipe_curve100k_noise_white_1.00e-01 pclouds/pipe_curve100k_noise_white_2.00e-02
# pclouds/pipe_curve100k_noise_white_1.00e-02 pclouds/pipe_curve100k_noise_white_3.00e-02
# pclouds/pipe_curve100k_noise_white_2.00e-02 pclouds/pipe_curve100k_noise_white_4.00e-02
# pclouds/pipe_curve100k_noise_white_3.00e-02 pclouds/pipe_curve100k_noise_white_5.00e-02
# pclouds/pipe_curve100k_noise_white_4.00e-02 pclouds/pipe_curve100k_noise_white_6.00e-02
# pclouds/pipe_curve100k_noise_white_5.00e-02 pclouds/pipe_curve100k_noise_white_7.00e-02
# pclouds/pipe_curve100k_noise_white_6.00e-02 pclouds/pipe_curve100k_noise_white_8.00e-02
# pclouds/pipe_curve100k_noise_white_7.00e-02 pclouds/pipe_curve100k_noise_white_9.00e-02
# pclouds/pipe_curve100k_noise_white_8.00e-02 pclouds/sheet_analytic100k
# pclouds/pipe_curve100k_noise_white_9.00e-02 pclouds/sheet_analytic100k_noise_white_1.00e-01
# pclouds/sheet_analytic100k pclouds/sheet_analytic100k_noise_white_1.00e-02
# pclouds/sheet_analytic100k_noise_white_1.00e-01 pclouds/sheet_analytic100k_noise_white_2.00e-02
# pclouds/sheet_analytic100k_noise_white_1.00e-02 pclouds/sheet_analytic100k_noise_white_3.00e-02
# pclouds/sheet_analytic100k_noise_white_2.00e-02 pclouds/sheet_analytic100k_noise_white_4.00e-02
# pclouds/sheet_analytic100k_noise_white_3.00e-02 pclouds/sheet_analytic100k_noise_white_5.00e-02
# pclouds/sheet_analytic100k_noise_white_4.00e-02 pclouds/sheet_analytic100k_noise_white_6.00e-02
# pclouds/sheet_analytic100k_noise_white_5.00e-02 pclouds/sheet_analytic100k_noise_white_7.00e-02
# pclouds/sheet_analytic100k_noise_white_6.00e-02 pclouds/sheet_analytic100k_noise_white_8.00e-02
# pclouds/sheet_analytic100k_noise_white_7.00e-02 pclouds/sheet_analytic100k_noise_white_9.00e-02
# pclouds/sheet_analytic100k_noise_white_8.00e-02 pclouds/sphere100k
# pclouds/sheet_analytic100k_noise_white_9.00e-02 pclouds/sphere100k_ddist_minmax
# pclouds/sphere100k pclouds/sphere100k_ddist_minmax_layers
# pclouds/sphere100k_ddist_minmax pclouds/sphere100k_noise_white_1.00e-01
# pclouds/sphere100k_ddist_minmax_layers pclouds/sphere100k_noise_white_1.00e-02
# pclouds/sphere100k_noise_white_1.00e-01 pclouds/sphere100k_noise_white_2.00e-02
# pclouds/sphere100k_noise_white_1.00e-02 pclouds/sphere100k_noise_white_3.00e-02
# pclouds/sphere100k_noise_white_2.00e-02 pclouds/sphere100k_noise_white_4.00e-02
# pclouds/sphere100k_noise_white_3.00e-02 pclouds/sphere100k_noise_white_5.00e-02
# pclouds/sphere100k_noise_white_4.00e-02 pclouds/sphere100k_noise_white_6.00e-02
# pclouds/sphere100k_noise_white_5.00e-02 pclouds/sphere100k_noise_white_7.00e-02
# pclouds/sphere100k_noise_white_6.00e-02 pclouds/sphere100k_noise_white_8.00e-02
# pclouds/sphere100k_noise_white_7.00e-02 pclouds/sphere100k_noise_white_9.00e-02
# pclouds/sphere100k_noise_white_8.00e-02 pclouds/sphere_analytic100k
# pclouds/sphere100k_noise_white_9.00e-02 pclouds/sphere_analytic100k_noise_white_1.00e-01
# pclouds/sphere_analytic100k pclouds/sphere_analytic100k_noise_white_1.00e-02
# pclouds/sphere_analytic100k_noise_white_1.00e-01 pclouds/sphere_analytic100k_noise_white_2.00e-02
# pclouds/sphere_analytic100k_noise_white_1.00e-02 pclouds/sphere_analytic100k_noise_white_3.00e-02
# pclouds/sphere_analytic100k_noise_white_2.00e-02 pclouds/sphere_analytic100k_noise_white_4.00e-02
# pclouds/sphere_analytic100k_noise_white_3.00e-02 pclouds/sphere_analytic100k_noise_white_5.00e-02
# pclouds/sphere_analytic100k_noise_white_4.00e-02 pclouds/sphere_analytic100k_noise_white_6.00e-02
# pclouds/sphere_analytic100k_noise_white_5.00e-02 pclouds/sphere_analytic100k_noise_white_7.00e-02
# pclouds/sphere_analytic100k_noise_white_6.00e-02 pclouds/sphere_analytic100k_noise_white_8.00e-02
# pclouds/sphere_analytic100k_noise_white_7.00e-02 pclouds/sphere_analytic100k_noise_white_9.00e-02
# pclouds/sphere_analytic100k_noise_white_8.00e-02 pclouds/star_halfsmooth100k
# pclouds/sphere_analytic100k_noise_white_9.00e-02 pclouds/star_halfsmooth100k_ddist_minmax
# pclouds/star_halfsmooth100k pclouds/star_halfsmooth100k_ddist_minmax_layers
# pclouds/star_halfsmooth100k_ddist_minmax pclouds/star_halfsmooth100k_noise_white_1.00e-01
# pclouds/star_halfsmooth100k_ddist_minmax_layers pclouds/star_halfsmooth100k_noise_white_1.00e-02
# pclouds/star_halfsmooth100k_noise_white_1.00e-01 pclouds/star_halfsmooth100k_noise_white_2.00e-02
# pclouds/star_halfsmooth100k_noise_white_1.00e-02 pclouds/star_halfsmooth100k_noise_white_3.00e-02
# pclouds/star_halfsmooth100k_noise_white_2.00e-02 pclouds/star_halfsmooth100k_noise_white_4.00e-02
# pclouds/star_halfsmooth100k_noise_white_3.00e-02 pclouds/star_halfsmooth100k_noise_white_5.00e-02
# pclouds/star_halfsmooth100k_noise_white_4.00e-02 pclouds/star_halfsmooth100k_noise_white_6.00e-02
# pclouds/star_halfsmooth100k_noise_white_5.00e-02 pclouds/star_halfsmooth100k_noise_white_7.00e-02
# pclouds/star_halfsmooth100k_noise_white_6.00e-02 pclouds/star_halfsmooth100k_noise_white_8.00e-02
# pclouds/star_halfsmooth100k_noise_white_7.00e-02 pclouds/star_halfsmooth100k_noise_white_9.00e-02
# pclouds/star_halfsmooth100k_noise_white_8.00e-02 pclouds/star_sharp100k
# pclouds/star_halfsmooth100k_noise_white_9.00e-02 pclouds/star_sharp100k_ddist_minmax
# pclouds/star_sharp100k pclouds/star_sharp100k_ddist_minmax_layers
# pclouds/star_sharp100k_ddist_minmax pclouds/star_sharp100k_noise_white_1.00e-01
# pclouds/star_sharp100k_ddist_minmax_layers pclouds/star_sharp100k_noise_white_1.00e-02
# pclouds/star_sharp100k_noise_white_1.00e-01 pclouds/star_sharp100k_noise_white_2.00e-02
# pclouds/star_sharp100k_noise_white_1.00e-02 pclouds/star_sharp100k_noise_white_3.00e-02
# pclouds/star_sharp100k_noise_white_2.00e-02 pclouds/star_sharp100k_noise_white_4.00e-02
# pclouds/star_sharp100k_noise_white_3.00e-02 pclouds/star_sharp100k_noise_white_5.00e-02
# pclouds/star_sharp100k_noise_white_4.00e-02 pclouds/star_sharp100k_noise_white_6.00e-02
# pclouds/star_sharp100k_noise_white_5.00e-02 pclouds/star_sharp100k_noise_white_7.00e-02
# pclouds/star_sharp100k_noise_white_6.00e-02 pclouds/star_sharp100k_noise_white_8.00e-02
# pclouds/star_sharp100k_noise_white_7.00e-02 pclouds/star_sharp100k_noise_white_9.00e-02
# pclouds/star_sharp100k_noise_white_8.00e-02 pclouds/star_smooth100k
# pclouds/star_sharp100k_noise_white_9.00e-02 pclouds/star_smooth100k_ddist_minmax
# pclouds/star_smooth100k pclouds/star_smooth100k_ddist_minmax_layers
# pclouds/star_smooth100k_ddist_minmax pclouds/star_smooth100k_noise_white_1.00e-01
# pclouds/star_smooth100k_ddist_minmax_layers pclouds/star_smooth100k_noise_white_1.00e-02
# pclouds/star_smooth100k_noise_white_1.00e-01 pclouds/star_smooth100k_noise_white_2.00e-02
# pclouds/star_smooth100k_noise_white_1.00e-02 pclouds/star_smooth100k_noise_white_3.00e-02
# pclouds/star_smooth100k_noise_white_2.00e-02 pclouds/star_smooth100k_noise_white_4.00e-02
# pclouds/star_smooth100k_noise_white_3.00e-02 pclouds/star_smooth100k_noise_white_5.00e-02
# pclouds/star_smooth100k_noise_white_4.00e-02 pclouds/star_smooth100k_noise_white_6.00e-02
# pclouds/star_smooth100k_noise_white_5.00e-02 pclouds/star_smooth100k_noise_white_7.00e-02
# pclouds/star_smooth100k_noise_white_6.00e-02 pclouds/star_smooth100k_noise_white_8.00e-02
# pclouds/star_smooth100k_noise_white_7.00e-02 pclouds/star_smooth100k_noise_white_9.00e-02
# pclouds/star_smooth100k_noise_white_8.00e-02 pclouds/tortuga100k
# pclouds/star_smooth100k_noise_white_9.00e-02 pclouds/tortuga100k_ddist_minmax
# pclouds/tortuga100k pclouds/tortuga100k_ddist_minmax_layers
# pclouds/tortuga100k_ddist_minmax pclouds/tortuga100k_noise_white_1.00e-01
# pclouds/tortuga100k_ddist_minmax_layers pclouds/tortuga100k_noise_white_1.00e-02
# pclouds/tortuga100k_noise_white_1.00e-01 pclouds/tortuga100k_noise_white_2.00e-02
# pclouds/tortuga100k_noise_white_1.00e-02 pclouds/tortuga100k_noise_white_3.00e-02
# pclouds/tortuga100k_noise_white_2.00e-02 pclouds/tortuga100k_noise_white_4.00e-02
# pclouds/tortuga100k_noise_white_3.00e-02 pclouds/tortuga100k_noise_white_5.00e-02
# pclouds/tortuga100k_noise_white_4.00e-02 pclouds/tortuga100k_noise_white_6.00e-02
# pclouds/tortuga100k_noise_white_5.00e-02 pclouds/tortuga100k_noise_white_7.00e-02
# pclouds/tortuga100k_noise_white_6.00e-02 pclouds/tortuga100k_noise_white_8.00e-02
# pclouds/tortuga100k_noise_white_7.00e-02 pclouds/tortuga100k_noise_white_9.00e-02
# 111
